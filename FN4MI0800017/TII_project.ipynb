# %% [markdown]
# # Работен notebook към курсовата работа
# ### **!** Програмите по-долу разчитат на конкретен път до тях (още по-конкретно използват връзка с *Google Drive*) **!**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Създаване на токените, използвайки **Tokenizer**

# %%
# !cd drive/MyDrive/TII_project/  && python generateTokens.py

# %% [markdown]
# ### Подготовка на корпусите (необходимо е да се изпълни при промяна на токени)

# %%
 import nltk

# !cd drive/MyDrive/TII_project/  && python run.py prepare

# %% [markdown]
# ### Обучение на нов модел или допълнително обучение на **NMTmodel**

# %%
# !cd drive/MyDrive/TII_project/  &&  python run.py train

# %%
# !cd drive/MyDrive/TII_project/  && python run.py extratrain
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %% [markdown]
# ### Довършване на текст и превод за даден префикс

# %%
# !cd drive/MyDrive/TII_project/  && python run.py generate "<S>New members were"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <S>New members were
# ...

# %% [markdown]
# ### Превеждане на цял корпус в посочен файл,, измерване на **BLEU score** и перплексия

# %%
# !cd drive/MyDrive/TII_project/  && python run.py translate "en_bg_data/test.en" "final"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Loading file: en_bg_data/test.en
# ...

# %%
# !cd drive/MyDrive/TII_project/  && python run.py bleu "en_bg_data/test.bg" "final"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Loading file: en_bg_data/test.bg
# Loading file: final
# Corpus BLEU:  41.86517227616488

# %%
# !cd drive/MyDrive/TII_project/  && python run.py perplexity "en_bg_data/dev.en" "en_bg_data/dev.bg"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %% [markdown]
# ### Ръчно създаване на токени (**Byte-Pair Encoding**)

# %%
# !cd drive/MyDrive/TII_project/  && python bpe_prepare.py 7000
# Out:
# Streaming output truncated to the last 5000 lines.
# Tokens: 2002/7000
# Tokens: 2003/7000
# Tokens: 2004/7000
# Tokens: 2005/7000
# Tokens: 2006/7000
# Tokens: 2007/7000
# Tokens: 2008/7000
# Tokens: 2009/7000
# Tokens: 2010/7000
# Tokens: 2011/7000
# Tokens: 2012/7000
# Tokens: 2013/7000
# Tokens: 2014/7000
# Tokens: 2015/7000
# Tokens: 2016/7000
# Tokens: 2017/7000
# Tokens: 2018/7000
# Tokens: 2019/7000
# Tokens: 2020/7000
# Tokens: 2021/7000
# Tokens: 2022/7000
# Tokens: 2023/7000
# Tokens: 2024/7000
# Tokens: 2025/7000
# Tokens: 2026/7000
# Tokens: 2027/7000
# Tokens: 2028/7000
# Tokens: 2029/7000
# Tokens: 2030/7000
# Tokens: 2031/7000
# Tokens: 2032/7000
# Tokens: 2033/7000
# Tokens: 2034/7000
# Tokens: 2035/7000
# Tokens: 2036/7000
# Tokens: 2037/7000
# Tokens: 2038/7000
# Tokens: 2039/7000
# Tokens: 2040/7000
# Tokens: 2041/7000
# Tokens: 2042/7000
# Tokens: 2043/7000
# Tokens: 2044/7000
# Tokens: 2045/7000
# Tokens: 2046/7000
# Tokens: 2047/7000
# Tokens: 2048/7000
# ...
